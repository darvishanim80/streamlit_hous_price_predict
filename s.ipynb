# %%
from sklearn.experimental import enable_iterative_imputer
import pandas as pd
import numpy as np
from sklearn.impute import IterativeImputer
from sklearn.preprocessing import LabelEncoder,OneHotEncoder,StandardScaler,Normalizer
from sklearn.model_selection import train_test_split 
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LinearRegression
# import seaborn as nan

# %%
df=pd.read_csv("dataset_divarR.csv")
df
# Out:
#             price                mantage  metrage     sal  otag   tabage  \
# 0      1350000000        chitgar-shomali       90  1404.0   2.0  ۸ از ۱۵
# 1     89999998976            saadat-abad      155  1404.0   3.0   ۶ از ۶
# 2     77999996928               velenjak      160  1403.0   2.0        ۳
# 3      2700000000              dolatkhah       57  1398.0   2.0        ۴
# 4     89999998976             farmaniyeh      215  1397.0   3.0   ۲ از ۶
# ...           ...                    ...      ...     ...   ...      ...
# 4867  27000000512               mirdamad       65  1399.0   1.0        ۳
# 4868  48000000000               amaniyeh      185  1390.0   3.0        ۲
# 4869  70000001024               niavaran      259  1388.0   4.0   ۶ از ۸
# 4870  14499999744  sazman-barname-jonubi       92  1385.0   2.0   ۲ از ۵
# 4871   3500000000           shahr-e-ziba       60  1400.0   2.0        ۲
#
#       vshed_status        lat       long  tehdad_vahed       asansor  \
# ...

# %%
df.describe()
# Out:
#               price       metrage          sal         otag          lat  \
# count  4.872000e+03  4.872000e+03  4823.000000  4846.000000  4872.000000
# mean   1.829965e+11  2.831102e+03  1395.431474     2.004333    35.727559
# std    4.071228e+12  1.413904e+05     8.495090     0.752966     0.040562
# min    1.000000e+03  8.000000e+00  1371.000000     1.000000    35.607664
# 25%    5.900000e+09  6.300000e+01  1388.000000     1.000000    35.695214
# 50%    1.350000e+10  8.750000e+01  1398.000000     2.000000    35.733053
# 75%    2.750000e+10  1.210000e+02  1404.000000     2.000000    35.755656
# max    1.820000e+14  8.815900e+06  1404.000000     4.000000    35.822610
#
#               long  tehdad_vahed
# count  4872.000000   2700.000000
# mean     51.374079      2.094444
# std       0.087658      1.551502
# min      51.020869      1.000000
# 25%      51.315427      1.000000
# 50%      51.370052      2.000000
# 75%      51.451312      2.000000
# max      51.602581      8.000000

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4872 entries, 0 to 4871
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         4872 non-null   int64
#  1   mantage       4872 non-null   str
#  2   metrage       4872 non-null   int64
#  3   sal           4823 non-null   float64
#  4   otag          4846 non-null   float64
#  5   tabage        4872 non-null   str
#  6   vshed_status  4872 non-null   str
#  7   lat           4872 non-null   float64
#  8   long          4872 non-null   float64
#  9   tehdad_vahed  2700 non-null   float64
#  10  asansor       4872 non-null   str
#  11  parking       4872 non-null   str
#  12  anbari        4872 non-null   str
# dtypes: float64(5), int64(2), str(6)
# memory usage: 494.9 KB
# price              0
# mantage            0
# metrage            0
# sal               49
# otag              26
# tabage             0
# vshed_status       0
# lat                0
# ...

# %%
df["anbari"].value_counts()
str_to_o1=["vshed_status","asansor","parking","anbari"]

df["vshed_status"]=df["vshed_status"].replace("بازسازی شده",True)
df["vshed_status"]=df["vshed_status"].replace("بازسازی نشده",False)


df["asansor"]=df["asansor"].replace("آسانسور دارد",True)
df["asansor"]=df["asansor"].replace("آسانسور ندارد",False)


df["parking"]=df["parking"].replace("پارگینگ دارد",True)
df["parking"]=df["parking"].replace("پارگینگ ندارد",False)


df["anbari"]=df["anbari"].replace("انباری دارد",True)
df["anbari"]=df["anbari"].replace("انباری ندارد",False)

# %%
df
df.info()
df["parking"].value_counts()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4872 entries, 0 to 4871
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         4872 non-null   int64
#  1   mantage       4872 non-null   str
#  2   metrage       4872 non-null   int64
#  3   sal           4823 non-null   float64
#  4   otag          4846 non-null   float64
#  5   tabage        4872 non-null   str
#  6   vshed_status  4872 non-null   object
#  7   lat           4872 non-null   float64
#  8   long          4872 non-null   float64
#  9   tehdad_vahed  2700 non-null   float64
#  10  asansor       4872 non-null   object
#  11  parking       4872 non-null   object
#  12  anbari        4872 non-null   object
# dtypes: float64(5), int64(2), object(4), str(2)
# memory usage: 494.9+ KB
# parking
# True     4026
# False     846
# Name: count, dtype: int64

# %%
df['parking'] = df['parking'].astype(bool)
df['anbari'] = df['anbari'].astype(bool)
df['asansor'] = df['asansor'].astype(bool)
df['vshed_status'] = df['vshed_status'].astype(bool)
df["parking"].value_counts()
df.info()
df["parking"].value_counts()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4872 entries, 0 to 4871
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         4872 non-null   int64
#  1   mantage       4872 non-null   str
#  2   metrage       4872 non-null   int64
#  3   sal           4823 non-null   float64
#  4   otag          4846 non-null   float64
#  5   tabage        4872 non-null   str
#  6   vshed_status  4872 non-null   bool
#  7   lat           4872 non-null   float64
#  8   long          4872 non-null   float64
#  9   tehdad_vahed  2700 non-null   float64
#  10  asansor       4872 non-null   bool
#  11  parking       4872 non-null   bool
#  12  anbari        4872 non-null   bool
# dtypes: bool(4), float64(5), int64(2), str(2)
# memory usage: 361.7 KB
# parking
# True     4026
# False     846
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# price              0
# mantage            0
# metrage            0
# sal               49
# otag              26
# tabage             0
# vshed_status       0
# lat                0
# long               0
# tehdad_vahed    2172
# asansor            0
# parking            0
# anbari             0
# dtype: int64

# %%
df.dropna(subset=['sal'], inplace=True)
df.dropna(subset=['otag'], inplace=True)

# %%
df.isnull().sum()
# Out:
# price              0
# mantage            0
# metrage            0
# sal                0
# otag               0
# tabage             0
# vshed_status       0
# lat                0
# long               0
# tehdad_vahed    2129
# asansor            0
# parking            0
# anbari             0
# dtype: int64

# %%
len(df["mantage"].unique())
# Out:
# 318

# %%
dummis= pd.get_dummies(df['mantage'], prefix='mantage')

df=pd.concat([df,dummis],axis=1)
df.drop("mantage",axis=1,inplace=True)

# %%
df["sal"].isnull().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (4797, 648)

# %%
df.columns
# Out:
# Index(['price', 'metrage', 'sal', 'otag', 'tabage', 'vshed_status', 'lat',
#        'long', 'tehdad_vahed', 'asansor',
#        ...
#        'mantage_yaftabad', 'mantage_yakhchi-abad', 'mantage_yousef-abad',
#        'mantage_zafar', 'mantage_zafaraniyeh', 'mantage_zahed-gilani',
#        'mantage_zamzam', 'mantage_zargandeh', 'mantage_zarkesh',
#        'mantage_zehtabi'],
#       dtype='str', length=648)

# %%
df["tabage"].unique()

# %%
imputer=IterativeImputer()
df=imputer.fit_transform(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 2
#       1 imputer=IterativeImputer()
# ----> 2 df=imputer.fit_transform(df)
#
# File c:\Users\Mohammad\Desktop\strimlist\myenv\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# ...

# %%
df.shape
# Out:
# (4797, 578)
